# %%
import pandas as pd
import numpy as np

# %%
s1 = pd.Series([1, 2, 3, 4, 5])
print(s1)
s2 = pd.Series([1, 2, 3, 4, 5], index=['a', 'b', 'c', 'd', 'e'])
print(s2)
s3 = pd.Series({'a': 10, 'b': 20, 'c': 30})
print(s3)
s4 = pd.Series(np.random.randn(5))
print(s4)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# a    10
# b    20
# c    30
# dtype: int64
# 0   -1.502733
# 1   -0.882317
# 2    0.181906
# 3   -2.320678
# 4    1.218514
# dtype: float64

# %%
from flask.config import T


df1 = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Paris', 'London']
})

df2 = pd.DataFrame([
        {'Name' : 'Arslan' , 'Age' : 34 , 'city' : 'Lahore'},
        {'Name' : 'Ash' , 'Age' : 27 , 'city' : 'Islamabad'},
        {'Name' : 'Khan Baba' , 'Age' : 25 , 'city' : 'Peshawar'},
        {'Name' : 'Noman' , 'Age' : 20 , 'city' : 'Gujranwala'},
        {'Name' : 'Asif' , 'Age' : 24 , 'city' : 'UK'},
        {'Name' : 'Arslan' , 'Age' : 34 , 'city' : 'Lahore'},
        {'Name' : 'Ash' , 'Age' : 27 , 'city' : 'Islamabad'},
        {'Name' : 'Khan Baba' , 'Age' : 25 , 'city' : 'Peshawar'},
        {'Name' : 'Noman' , 'Age' : 20 , 'city' : 'Gujranwala'},
        {'Name' : 'Asif' , 'Age' : 24 , 'city' : 'UK'}
])
# print(df2)
# df2.sort_values('Age')
# df2.sort_values('Name')
# df2.sort_values('city')
# print(df2.shape)
# print(df2.info)
# print(df2.describe)
print(df2[df2['Age'] > 28])
print(df2[(df2['Age'] > 25) & (df2['city'] == 'Lahore')])
# Out:
#      Name  Age    city
# 0  Arslan   34  Lahore
# 5  Arslan   34  Lahore
#      Name  Age    city
# 0  Arslan   34  Lahore
# 5  Arslan   34  Lahore
