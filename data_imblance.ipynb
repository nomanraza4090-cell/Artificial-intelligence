# %%
import pandas as pd
import numpy as np

# Visualization (optional)
import seaborn as sns
import matplotlib.pyplot as plt

# ML
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
df = pd.read_csv("E:\\Dev\\Data Sets\\creditcard.csv", 
                   )
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
print(df.isnull().sum())
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
# df.fillna(method='bfill', inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
print('No Frauds', round(df['Class'].value_counts()[0]/len(df) * 100,3), '% of the dataset')
print('Frauds', round(df['Class'].value_counts()[1]/len(df) * 100,2), '% of the dataset')
# Out:
# No Frauds 99.833 % of the dataset
# Frauds 0.17 % of the dataset

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 6))
df['Class'].value_counts().plot.pie(autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('distribution')
ax[0].set_ylabel('')
sns.countplot(x='Class', data=df, ax=ax[1])
ax[1].set_title('Class')
plt.show()

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
from sklearn.preprocessing import RobustScaler,StandardScaler
# scaler = RobustScaler()
scaler = StandardScaler()

# %%
# Standardizing Time and Amount variables
df['Amount'] = scaler.fit_transform(df['Amount'].values.reshape(-1,1))
df['Time'] = scaler.fit_transform(df['Time'].values.reshape(-1,1))
df.head()
# Out:
#        Time        V1        V2        V3        V4        V5        V6  \
# 0 -1.996823 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1 -1.996823  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2 -1.996802 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3 -1.996802 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4 -1.996781 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928
# 1 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575
# 4  0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %%
# We apply the hold out method and divide the data set into training and testing (80%, 20%).
X = df.drop("Class", axis=1)
y = df["Class"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=2)

# %%
y.value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
X_train
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 132587 -0.311116  1.081439 -0.744099 -0.496759 -1.365694 -0.590818 -0.989495
# 45970  -1.099937  0.875127 -0.458188  1.083894  1.129629 -0.679143  0.959492
# 5618   -1.874648 -0.882492  1.118103  1.373908  0.297075 -0.162550  0.296476
# 32015  -1.225882 -2.996404  0.511195 -1.900544 -2.919905  1.346287  2.820428
# 256152  1.321560 -0.240767  1.053526  0.557865 -0.429743 -0.096926 -1.653227
# ...          ...       ...       ...       ...       ...       ...       ...
# 34004  -1.207686  1.158312 -0.225695  0.948764  0.891092 -1.004396 -0.415928
# 84746  -0.723829 -1.851655 -1.001499  1.464520  0.836462 -0.462833  0.705960
# 96185  -0.614185 -1.678212  1.244794  0.947874 -2.101099 -0.811015 -1.037444
# 203974  0.847601  0.838693 -3.276784 -1.592755 -2.202567 -1.264033  0.470984
# 101260 -0.569409 -0.919412 -0.015864  2.476950 -1.394001 -0.527244  0.054240
#
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### Train the model on imblance dataset

# %%
model = LogisticRegression(
    
)

model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9991717477883904

# %% [markdown]
# The accuracy score of the model we created is 0.999. We can say that our model works perfectly, right? Let's take a look at the Confusion Matrix to examine its performance.

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56661
#            1       0.79      0.61      0.69        85
#
#     accuracy                           1.00     56746
#    macro avg       0.89      0.81      0.84     56746
# weighted avg       1.00      1.00      1.00     56746

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)

# Create confusion matrix graph
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# [[56647    14]
#  [   33    52]]

# %% [markdown]
#  ###  Class Imbalance
# Class 0: 56,661 samples (99.85% of data)
#
# Class 1: Only 85 samples (0.15% of data)
#
# This is a highly imbalanced dataset where Class 0 dominates.
#
# ### 2. Accuracy is Misleading
# 99.9% accuracy sounds impressive, but it's deceptive
#
# The model achieves this by mostly predicting Class 0 correctly
#
# It's essentially guessing the majority class and getting it right most of the time
#
# ### 3. Poor Performance on Minority Class (Class 1)
# Class 1 metrics:
#
# Precision (0.79): 79% of predicted Class 1 are correct
#
# Recall (0.61): Only 61% of actual Class 1 are caught
#
# F1-score (0.69): Poor balance between precision and recall
#
# ### 4. Confusion Matrix Analysis
#    # Class 0: 56,647 correct, 14 misclassified as Class 1
#    # Class 1: 52 correct, 33 misclassified as Class 0
# For Class 1 (the minority class):
#
# True Positives: 52 (correctly identified)
#
# False Negatives: 33 (missed - predicted as Class 0)
#
# Missed rate: 33/85 = 38.8% of Class 1 cases are missed!
#
# What This Means
# Strengths:
# Excellent at identifying Class 0 (99.98% accuracy)
#
# Low false positives for Class 1 (only 14 false alarms)
#
# Weaknesses:
# Fails to detect ~39% of actual Class 1 cases
#
# In real-world applications, this could be critical if Class 1 represents:
#
# Fraudulent transactions
#
# Disease cases
#
# Security threats

# %% [markdown]
# 1. Choosing the Right Metric¶
# When dealing with imbalanced datasets, it is important to choose the right metric to evaluate the performance of the model. Traditional metrics, such as accuracy, precision, and recall, may not be appropriate for imbalanced datasets because they do not take into account the distribution of the classes in the data.
#
# One metric that is often used for imbalanced datasets is the F1 score. The F1 score is the harmonic mean of precision and recall, and it provides a balance between the two metrics. It is calculated as follows:
#
# F1 = 2 * (precision * recall) / (precision + recall)
#
# Another metric that is often used for imbalanced datasets is the area under the receiver operating characteristic curve (AUC-ROC). The AUC-ROC is a measure of the model's ability to distinguish between positive and negative classes. It is calculated by plotting the true positive rate (TPR) against the false positive rate (FPR) at different classification thresholds. AUC-ROC values range from 0.5 (random guessing) to 1.0 (perfect classification).

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score, roc_curve

# Get predicted probabilities
y_pred_proba = model.predict_proba(X_test)[:, 1]
auc = roc_auc_score(y_test, y_pred_proba)
print("AUC = %.3f" % auc)

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

# Plot ROC curve
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, label=f'AUC = {auc:.3f}')
plt.plot([0, 1], [0, 1], '--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# AUC = 0.982

# %% [markdown]
# ### What is ROC Curve?
# ROC (Receiver Operating Characteristic) curve shows how well your model distinguishes between two classes (fraud vs. normal transactions).
#
# It plots:
#
# X-axis: False Positive Rate (FPR) = Fraud predicted when actually normal
#
# Y-axis: True Positive Rate (TPR) = Fraud correctly detected

# %% [markdown]
# ### Why AUC is Important for Fraud Detection
# 1. Handles Imbalanced Data
# Your fraud dataset has very few fraud cases (class 1). AUC works well here because:
#
# Accuracy is misleading (99.9% accuracy but missing 39% of fraud)
#
# AUC focuses on ranking ability, not just accuracy
#
# 2. Balanced Evaluation
# AUC considers both:
#
# Sensitivity (catching fraud)
#
# Specificity (not flagging normal as fraud)
#
# 3. Threshold Independent
# Unlike confusion matrix that depends on a specific threshold (0.5), AUC evaluates model performance across ALL thresholds.
#
# Practical Meaning of AUC = 0.982
# In simple terms:
#
# If you randomly pick ONE fraud transaction and ONE normal transaction
#
# Your model will correctly rank the fraud higher 98.2% of the time
#
# Only 1.8% chance it gets the ranking wrong
#
# For your bank/fraud system:
#
# At the optimal threshold, you can catch ~95% of fraud
#
# While only flagging ~5% of normal transactions as suspicious
#
# The model can be tuned based on business needs:
#
# Lower threshold = Catch more fraud, but more false alarms
#
# Higher threshold = Fewer false alarms, but might miss fraud

# %% [markdown]
# ### sampling Techniques

# %%
# Implementing RandomOver Sampling (Applying to the training set)
from imblearn.over_sampling import RandomOverSampler
oversample = RandomOverSampler(sampling_strategy='minority')
X_randomover, y_randomover = oversample.fit_resample(X_train, y_train)

# %%
y_randomover.value_counts()
# Out:
# Class
# 0    226592
# 1    226592
# Name: count, dtype: int64

# %%
# training the model and its success rate
model.fit(X_randomover, y_randomover)
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.3f%%" % (accuracy))
# Out:
# Accuracy: 0.977%

# %%
cm = confusion_matrix(y_test, y_pred)
print(cm)

# Create confusion matrix graph
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# [[55376  1285]
#  [    7    78]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     56661
#            1       0.06      0.92      0.11        85
#
#     accuracy                           0.98     56746
#    macro avg       0.53      0.95      0.55     56746
# weighted avg       1.00      0.98      0.99     56746

# %%
# Get predicted probabilities
y_pred_proba = model.predict_proba(X_test)[:, 1]
auc = roc_auc_score(y_test, y_pred_proba)
print("AUC = %.3f" % auc)

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)

# Plot ROC curve
plt.figure(figsize=(6, 5))
plt.plot(fpr, tpr, label=f'AUC = {auc:.3f}')
plt.plot([0, 1], [0, 1], '--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# AUC = 0.978

# %% [markdown]
# # Fraud Detection Model Analysis: Before vs. After Sampling
#
# ##  Dataset Overview
#
# Your fraud detection dataset has a **severe class imbalance**:
#
# | Class | Description | Count | Percentage |
# |-------|-------------|-------|------------|
# | **Class 0** | Normal Transactions | 56,661 | 99.85% |
# | **Class 1** | Fraud Transactions | 85 | 0.15% |
#
# **Imbalance Ratio**: 666 normal transactions for every 1 fraud transaction
#
# ---
#
# ##  Before Sampling (Imbalanced Data)
#
# ### Results
#
# Accuracy: 99.92%
# Class 1: Precision = 0.79, Recall = 0.61, F1 = 0.69
#
# Confusion Matrix:
# [[56647 14]
# [ 33 52]]

# %% [markdown]
# ###  Interpretation
#
# | Metric | Value | Meaning |
# |--------|------|--------|
# | Recall (Fraud) | 61% | Missed 39% of fraud |
# | Precision (Fraud) | 79% | 21% false alarms |
# | False Negatives | 33 | ❌ High fraud loss |
#
# ###  Problem
# - Model biased toward **Normal class**
# - Misses **39% of fraud cases**
#
# ---
#
# #  After Sampling (Balanced Data)
#
# ###  Results
# Accuracy: 97.7%
#
# Class 1:
# Precision = 0.06
# Recall = 0.92
# F1 = 0.11
#
# Confusion Matrix:
# [[55376 1285]
# [ 7 78]]

# %% [markdown]
# ###  Interpretation
#
# | Metric | Value | Meaning |
# |--------|------|--------|
# | Recall (Fraud) | 92% | ✅ Excellent detection |
# | Precision (Fraud) | 6% | ❌ Many false alarms |
# | False Negatives | 7 | ✅ Very low |
# | False Positives | 1,285 | ❌ High |
#
# ---
#
# #  What Sampling Changed
#
# ```python
# # Before
# Normal: 56,661
# Fraud: 85
# Ratio: 666:1
#
# # After (Balanced)
# Normal: ~56,661
# Fraud: ~56,661
# Ratio: 1:1

# %% [markdown]
# Business Impact
# Assume $1000 per fraud
# Before:
# 33 missed → $33,000 loss
# After:
# 7 missed → $7,000 loss
# 💡 Savings:
# $26,000 saved
