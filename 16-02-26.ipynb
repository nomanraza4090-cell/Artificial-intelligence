# %% [markdown]
# Display Variables

# %%
a = 23
b = 45
nomi= "ali"
print(a+b)
print(nomi)
# Out:
# 68
# ali

# %%
x = 3
y = 7
z = 2
#print(z)
#z = x*y
#print(z)
#age = 29
#print(age)
a = x+y*z
print(a)
# Out:
# 17

# %%
a = 'ali'
b = '89'
c = '2.78'
d = '34'
e = 'djengo'
print(a,b,c,d,e)
# Out:
# ali 89 2.78 34 djengo

# %%
x =  60
if x <= 50:
    print("true")
else:
    print("false")
# Out:
# false

# %%
mylist=['blue','yellow','green', 'black']

# %%
print(mylist)
# Out:
# ['blue', 'yellow', 'green', 'black']

# %%
mylist.append('purple')

# %%
print(mylist)
# Out:
# ['blue', 'yellow', 'green', 'black', 'purple']

# %%
x1 = "python"
x2 = "khan"
concatenate = x1+x2
print(concatenate)
# Out:
# pythonkhan

# %%
txt = "Nomi"
repeat = txt*3
print(repeat)
# Out:
# NomiNomiNomi

# %%
a = "Nomi"
print("name" , a[0])
# Out:
# name N

# %%
name = "Ahmad ali "
name[2:3]
print(len(name))
print(name.lower())
print(name.upper())
print(name.replace("m" , "h"))
print("ali" in name)
# Out:
# 10
# ahmad ali
# AHMAD ALI
# Ahhad ali
# True

# %%
'''name = input("Enter your name")
print("My name is " , name)
age = int(input("enter age"))
print(age)
age = float(input("enter age"))
print(age)
num = "100"
age = int(num)
print(age)
print(type(age))'''
# Out:
# 'name = input("Enter your name")\nprint("My name is " , name)\nage = int(input("enter age"))\nprint(age)\nage = float(input("enter age"))\nprint(age)\nnum = "100"\nage = int(num)\nprint(age)\nprint(type(age))'

# %%
num = 50
convert = str(num)
print(type(convert))
# Out:
# <class 'str'>

# %%
list = [1,2,3,4,5]
list.append(6)
print(list)
list.remove(3)
print(list)
print(list[0])
print(len(list))
tuple=[1,2,3]
print(tuple[2])
list[2]=8
print("after replace", list)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 4, 5, 6]
# 1
# 5
# 3
# after replace [1, 2, 8, 5, 6]

# %%
Dictionary={"name": "Noman" , "Age": 24}
print(Dictionary)
Dictionary ["city"] = "gujranwala"
print(Dictionary)
print(Dictionary.keys())
set={1,2,3,4,1,2,3,4,}
set.add(5)
print(set)
set.remove(3)
print(set)
print(1 in set)
# Out:
# {'name': 'Noman', 'Age': 24}
# {'name': 'Noman', 'Age': 24, 'city': 'gujranwala'}
# dict_keys(['name', 'Age', 'city'])
# {1, 2, 3, 4, 5}
# {1, 2, 4, 5}
# True

# %%
num = float(input("enter ur number"))
if num > 0:
    print("number is positive")
else:
    print("number is negative")
# Out:
# number is positive

# %%
num = int(input("enter ur number"))
if num % 2 ==0:
    print("the number is Even")
else:
    print("the number is Odd")
# Out:
# the number is Even

# %%
num1 = int(input("Enter 1st number." ))
num2= int(input("Enter 2nd number." ))
if num1 > num2:
    print("1st number is greater then.")
elif num1 < num2:
    print("2nd number is greater")
else:
    print("Both numbers are equal")
# Out:
# 1st number is greater then.

# %%
marks = int(input("Enter your number"))
if marks >=90:
    print("Grade: A")
elif marks >=80:
    print("Grade: B")
elif marks >=70:
    print("Grade: C")
else:
    print("Grade: F")
# Out:
# Grade: F
