# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('Student.csv')
sns.set_style("whitegrid")
df.head(10)
# Out:
#    Student_ID       Name  Age  Gender Department  Semester  CGPA  \
# 0        1001  Student_0   24   Other       Math         3   NaN
# 1        1002  Student_1   21  Female         EE         1  3.94
# 2        1003  Student_2   22   Other         EE         5  2.44
# 3        1004  Student_3   24    Male         EE         4  3.47
# 4        1005  Student_4   20    Male         CS         2  3.53
# 5        1006  Student_5   22    Male       Math         1  3.86
# 6        1007  Student_6   22  Female       Math         3  2.06
# 7        1008  Student_7   24    Male    Physics         7  3.74
# 8        1009  Student_8   19  Female    Physics         6  3.05
# 9        1010  Student_9   20    Male    Physics         7  3.27
#
#    Attendance_Rate  Scholarship Admission_Date  Midterm_Marks  Final_Marks  \
# 0             61.0        False     2021-09-11             26           33
# 1             98.0        False     2020-01-26              0           39
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Student_ID           1030 non-null   int64
#  1   Name                 1030 non-null   str
#  2   Age                  1030 non-null   int64
#  3   Gender               1030 non-null   str
#  4   Department           1030 non-null   str
#  5   Semester             1030 non-null   int64
#  6   CGPA                 979 non-null    float64
#  7   Attendance_Rate      999 non-null    float64
#  8   Scholarship          1030 non-null   bool
#  9   Admission_Date       1030 non-null   str
#  10  Midterm_Marks        1030 non-null   int64
#  11  Final_Marks          1030 non-null   int64
#  12  City                 1030 non-null   str
#  13  Study_Hours_Per_Day  1030 non-null   int64
#  14  Fees_Paid            1008 non-null   str
# dtypes: bool(1), float64(2), int64(6), str(6)
# ...

# %%
df.describe()
# Out:
#         Student_ID          Age     Semester        CGPA  Attendance_Rate  \
# count  1030.000000  1030.000000  1030.000000  979.000000       999.000000
# mean   1486.373786    20.971845     4.448544    3.046558        74.733734
# std     296.048992     1.996154     2.270094    0.574487        14.213981
# min    1001.000000    18.000000     1.000000    2.000000        50.000000
# 25%    1228.250000    19.000000     3.000000    2.560000        63.000000
# 50%    1485.500000    21.000000     4.000000    3.090000        74.000000
# 75%    1742.750000    23.000000     6.000000    3.545000        87.000000
# max    2000.000000    24.000000     8.000000    4.000000        99.000000
#
#        Midterm_Marks  Final_Marks  Study_Hours_Per_Day
# count    1030.000000  1030.000000          1030.000000
# mean       14.845631    24.875728             6.062136
# std         8.877224    14.492520             3.149348
# min         0.000000     0.000000             1.000000
# ...

# %%
df.dtypes
# Out:
# Student_ID               int64
# Name                       str
# Age                      int64
# Gender                     str
# Department                 str
# Semester                 int64
# CGPA                   float64
# Attendance_Rate        float64
# Scholarship               bool
# Admission_Date             str
# Midterm_Marks            int64
# Final_Marks              int64
# City                       str
# Study_Hours_Per_Day      int64
# Fees_Paid                  str
# dtype: object

# %%
df.columns
# Out:
# Index(['Student_ID', 'Name', 'Age', 'Gender', 'Department', 'Semester', 'CGPA',
#        'Attendance_Rate', 'Scholarship', 'Admission_Date', 'Midterm_Marks',
#        'Final_Marks', 'City', 'Study_Hours_Per_Day', 'Fees_Paid'],
#       dtype='str')

# %%
df.duplicated().sum()
# Out:
# np.int64(30)

# %%
df.drop_duplicates(inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Student_ID              0
# Name                    0
# Age                     0
# Gender                  0
# Department              0
# Semester                0
# CGPA                   50
# Attendance_Rate        30
# Scholarship             0
# Admission_Date          0
# Midterm_Marks           0
# Final_Marks             0
# City                    0
# Study_Hours_Per_Day     0
# Fees_Paid              20
# dtype: int64

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# Student_ID             0
# Name                   0
# Age                    0
# Gender                 0
# Department             0
# Semester               0
# CGPA                   0
# Attendance_Rate        0
# Scholarship            0
# Admission_Date         0
# Midterm_Marks          0
# Final_Marks            0
# City                   0
# Study_Hours_Per_Day    0
# Fees_Paid              0
# dtype: int64

# %%
df.count()
# Out:
# Student_ID             904
# Name                   904
# Age                    904
# Gender                 904
# Department             904
# Semester               904
# CGPA                   904
# Attendance_Rate        904
# Scholarship            904
# Admission_Date         904
# Midterm_Marks          904
# Final_Marks            904
# City                   904
# Study_Hours_Per_Day    904
# Fees_Paid              904
# dtype: int64

# %% [markdown]
# ### Pivot Tables

# %%
# Calculate average CGPA by Department and Gender

pd.pivot_table(df, values='CGPA', index='Department', columns='Gender', aggfunc='mean',)
# Out:
# Gender        Female      Male     Other
# Department
# BBA         3.054138  3.003889  3.068679
# CS          2.977308  3.108750  3.094394
# EE          3.045833  3.020377  3.047451
# Math        3.018000  3.160339  3.004615
# Physics     2.993750  3.010588  3.075000

# %%
# Count number of students by Department and Fees Paid status
pd.pivot_table(df, values='Student_ID', index='Department', columns='Fees_Paid', aggfunc='count')
# Out:
# Fees_Paid   Full  Installment  Pending
# Department
# BBA           67           53       63
# CS            58           62       54
# EE            56           44       52
# Math          75           70       62
# Physics       74           44       70

# %%
# Calculate mean, maximum, and minimum of Midterm and Final marks by Department

pd.pivot_table(df,values=['Midterm_Marks', 'Final_Marks'], index='Department',aggfunc=['mean', 'max', 'min'])
# Out:
#                   mean                       max                       min  \
#            Final_Marks Midterm_Marks Final_Marks Midterm_Marks Final_Marks
# Department
# BBA          24.442623     14.808743          50            30           0
# CS           26.183908     14.373563          50            30           0
# EE           24.815789     14.440789          50            30           0
# Math         26.367150     14.884058          50            30           0
# Physics      22.436170     15.223404          50            30           0
#
#
#            Midterm_Marks
# Department
# BBA                    0
# CS                     0
# EE                     0
# Math                   0
# Physics                0

# %%
# Calculate total study hours per day by City, Department, and Semester

pd.pivot_table(df,values='Study_Hours_Per_Day',index=['City' , "Department"],columns="Semester" ,aggfunc='sum')
# Out:
# Semester                  1     2     3     4     5     6     7     8
# City       Department
# Faisalabad BBA         26.0  44.0  35.0  19.0  14.0  20.0  25.0  46.0
#            CS          12.0  22.0  24.0  54.0  19.0  35.0  14.0  12.0
#            EE          47.0  10.0   5.0  65.0  49.0  23.0  30.0  21.0
#            Math        18.0  31.0  28.0  69.0  18.0  11.0   1.0  19.0
#            Physics     14.0  47.0  34.0  29.0   9.0  22.0  19.0   NaN
# Islamabad  BBA         25.0  25.0  42.0  23.0  42.0  20.0  24.0  34.0
#            CS          20.0  26.0  19.0  33.0  21.0  11.0  29.0   NaN
#            EE          27.0   NaN  37.0  35.0  24.0  13.0  14.0  32.0
#            Math        47.0  28.0  41.0  10.0   9.0  60.0  64.0   5.0
#            Physics      6.0  42.0  22.0  31.0  27.0  37.0  39.0  18.0
# Karachi    BBA         14.0  17.0  36.0  12.0  26.0  42.0  53.0  36.0
#            CS          22.0  46.0  18.0  13.0  44.0  38.0  11.0  31.0
# ...

# %%
# Count number of students with scholarships by City and Department

pd.pivot_table(df, values="Scholarship" , index="City" , columns="Department" , aggfunc="sum")
# Out:
# Department  BBA  CS  EE  Math  Physics
# City
# Faisalabad    5   5   9     8        5
# Islamabad     6   4   6     9        3
# Karachi       7  10  10    11        8
# Lahore       11   6   4     9       11
# Multan       10  14   2     5        6

# %%
# Calculate average CGPA and Attendance Rate by Gender and Scholarship status, including overall totals

pd.pivot_table(df,values=['CGPA', 'Attendance_Rate'],index='Gender',columns='Scholarship',aggfunc='mean',margins=True , margins_name='Total Average')
# Out:
#               Attendance_Rate                               CGPA            \
# Scholarship             False       True Total Average     False      True
# Gender
# Female              76.179825  75.046875     75.931507  3.021930  3.000313
# Male                73.862903  76.683333     74.412338  3.028871  3.174500
# Other               73.622951  74.916667     73.878289  3.065533  3.014333
# Total Average       74.515278  75.538043     74.723451  3.039097  3.061685
#
#
# Scholarship   Total Average
# Gender
# Female             3.017192
# Male               3.057240
# Other              3.055428
# Total Average      3.043695

# %%
pd.pivot_table(df , values="Final_Marks" , index="City" , columns="Department" , aggfunc="mean")
# Out:
# Department        BBA         CS         EE       Math    Physics
# City
# Faisalabad  26.028571  27.333333  28.000000  24.243243  20.066667
# Islamabad   23.897436  27.218750  27.206897  27.934783  22.500000
# Karachi     25.166667  26.189189  21.814815  25.204545  22.461538
# Lahore      24.972973  23.861111  23.853659  27.166667  22.280702
# Multan      22.222222  26.589744  22.363636  27.000000  25.000000

# %%
#pivot table to calculate the average attendance rate for each city and department with semester wise

pd.pivot_table(df , values="Attendance_Rate" , index=["City","Department"] , columns="Semester" , aggfunc="mean")
# Out:
# Semester                       1          2          3          4          5  \
# City       Department
# Faisalabad BBA         73.000000  77.166667  79.400000  82.333333  56.500000
#            CS          70.666667  70.250000  80.333333  77.875000  82.500000
#            EE          72.800000  54.000000  61.000000  71.750000  78.000000
#            Math        67.750000  68.000000  79.428571  76.700000  72.666667
#            Physics     76.000000  75.142857  72.285714  72.500000  74.000000
# Islamabad  BBA         79.800000  71.666667  72.000000  73.000000  74.666667
#            CS          67.166667  74.750000  69.500000  62.200000  71.833333
#            EE          63.500000        NaN  74.857143  78.400000  71.500000
#            Math        75.142857  65.200000  83.714286  89.000000  72.000000
#            Physics     62.500000  59.750000  83.750000  69.500000  67.250000
# Karachi    BBA         81.666667  77.250000  72.600000  66.333333  72.750000
# ...

# %% [markdown]
# ### Seaborn

# %%
# plt.figure(figsize=(8,6))
sns.lineplot(data=df, x="Department", y="CGPA",hue='City')
# Out:
# <Axes: xlabel='Department', ylabel='CGPA'>

# %% [markdown]
# #### Box Plot

# %%
sns.boxplot(data=df, x="Semester", y="CGPA")
# Out:
# <Axes: xlabel='Semester', ylabel='CGPA'>

# %%
sns.scatterplot(data=df, x="Gender", y="Attendance_Rate")
# Out:
# <Axes: xlabel='Gender', ylabel='Attendance_Rate'>

# %% [markdown]
# ### Pair Chart

# %%
sns.pairplot(df[["CGPA" , "Final_Marks" , "Study_Hours_Per_Day"]])

# %% [markdown]
# ### Heat Map

# %%
sns.heatmap(df.corr(numeric_only=True) , annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Bar Chart

# %%
df["Department"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Department'>

# %% [markdown]
# ### Matplotlib

# %%
df["Gender"].value_counts().plot(kind="pie")
# Out:
# <Axes: >

# %%
df["Department"].value_counts().plot(kind="pie")
# Out:
# <Axes: >

# %%
df["Age"].value_counts().plot(kind="pie")
# Out:
# <Axes: >

# %%
df["Scholarship"].value_counts().plot(kind="pie")
# Out:
# <Axes: >

# %%
import scipy.cluster.hierarchy as sch
sch.dendrogram(sch.linkage(df[['CGPA','Attendance_Rate']].dropna(), method='ward'))
# Out:
# {'icoord': [[15.0, 15.0, 25.0, 25.0],
#   [5.0, 5.0, 20.0, 20.0],
#   [35.0, 35.0, 45.0, 45.0],
#   [75.0, 75.0, 85.0, 85.0],
#   [65.0, 65.0, 80.0, 80.0],
#   [55.0, 55.0, 72.5, 72.5],
#   [40.0, 40.0, 63.75, 63.75],
#   [12.5, 12.5, 51.875, 51.875],
#   [115.0, 115.0, 125.0, 125.0],
#   [105.0, 105.0, 120.0, 120.0],
#   [95.0, 95.0, 112.5, 112.5],
#   [145.0, 145.0, 155.0, 155.0],
#   [175.0, 175.0, 185.0, 185.0],
#   [165.0, 165.0, 180.0, 180.0],
#   [150.0, 150.0, 172.5, 172.5],
#   [135.0, 135.0, 161.25, 161.25],
#   [103.75, 103.75, 148.125, 148.125],
#   [225.0, 225.0, 235.0, 235.0],
#   [215.0, 215.0, 230.0, 230.0],
#   [205.0, 205.0, 222.5, 222.5],
#   [195.0, 195.0, 213.75, 213.75],
#   [245.0, 245.0, 255.0, 255.0],
#   [265.0, 265.0, 275.0, 275.0],
#   [285.0, 285.0, 295.0, 295.0],
#   [270.0, 270.0, 290.0, 290.0],
#   [250.0, 250.0, 280.0, 280.0],
#   [204.375, 204.375, 265.0, 265.0],
#   [125.9375, 125.9375, 234.6875, 234.6875],
# ...

# %%
df['City'].map({'Lahore':'LHR', 'Karachi':'KHI', 'Islamabad':'ISB', 'Multan':'MUX', 'Faisalabad':'FSD'})
# Out:
# 1      LHR
# 2      FSD
# 3      FSD
# 4      KHI
# 6      ISB
#       ...
# 995    ISB
# 996    MUX
# 997    ISB
# 998    KHI
# 999    LHR
# Name: City, Length: 904, dtype: str

# %%
plt.hist(df["Final_Marks"])
# Out:
# (array([77., 99., 94., 95., 85., 80., 85., 99., 91., 99.]),
#  array([ 0.,  5., 10., 15., 20., 25., 30., 35., 40., 45., 50.]),
#  <BarContainer object of 10 artists>)

# %%
df.plot(kind='bar', x='City', y='CGPA', title='Average CGPA by City')
# Out:
# <Axes: title={'center': 'Average CGPA by City'}, xlabel='City'>

# %% [markdown]
# ### Map Chart

# %%
# city_coords = {
#     "Lahore": (31.5204, 74.3587),
#     "Karachi": (24.8607, 67.0011),
#     "Islamabad": (33.6844, 73.0479),
#     "Multan": (30.1575, 71.5249),
#     "Faisalabad": (31.4504, 73.1350)
# }
# df["Latitude"] = df["City"].map(lambda x: city_coords.get(x, (None, None))[0])
# df["Longitude"] = df["City"].map(lambda x: city_coords.get(x, (None, None))[1])
# import plotly.express as px

# fig = px.scatter_geo(
#     # city_counts,
#     lat="Latitude",
#     lon="Longitude",
#     size="Students",
#     hover_name="City",
#     title="Cities Students Come From"
# )

# fig.update_layout(title="Student Cities in Pakistan")
# fig.show()

# %%
import plotly.express as px

# City coordinates
city_coords = {
    "Lahore": (31.5204, 74.3587),
    "Karachi": (24.8607, 67.0011),
    "Islamabad": (33.6844, 73.0479),
    "Multan": (30.1575, 71.5249),
    "Faisalabad": (31.4504, 73.1350)
}

# Count students per city
city_counts = df["City"].value_counts().reset_index()
city_counts.columns = ["City", "Students"]

# Add coordinates
city_counts["Latitude"] = city_counts["City"].map(lambda x: city_coords.get(x, (None,None))[0])
city_counts["Longitude"] = city_counts["City"].map(lambda x: city_coords.get(x, (None,None))[1])

# Create map
fig = px.scatter_geo(
    city_counts,
    lat="Latitude",
    lon="Longitude",
    size="Students",
    hover_name="City",
    scope="asia",
    title="Student Cities in Pakistan"
)

# Focus map on Pakistan
fig.update_geos(
    showcountries=True,
    lataxis_range=[23,37],
    lonaxis_range=[60,78]
)

fig.show()
