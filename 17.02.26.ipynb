# %% [markdown]
# Values expressions and statements

# %%
x = 5
y = 2.4
age = 24
name = "Noman"
print(x , y)
if x > y:
    print("True")
else:
    print("False")
print(age)
print(x+y)
print(x*y)
if x >= y:
    print("True")
else:
    print("False")
print(3+7*2)
# Out:
# 5 2.4
# True
# 24
# 7.4
# 12.0
# True
# 17

# %% [markdown]
# sting opreations

# %%
name = "Noman Raza"
n2 = "Khan"
concatenate = name+ "" +n2
print(concatenate)
repeat = name*3
print(repeat)
print(n2[0])
name[0:4]
print(name)
print(len(name))
print(name.lower())
print(name.upper())
print(name.replace("n" , "N"))
print("Raza" in name)
# Out:
# Noman RazaKhan
# Noman RazaNoman RazaNoman Raza
# K
# Noman Raza
# 10
# noman raza
# NOMAN RAZA
# NomaN Raza
# True

# %% [markdown]
# Input , Type casting and comments

# %%
print(input("Enter your name."))
# Out:
# 2
