# %%
#create employe class that shows employe name and salary and add up bonus on the base of salary
class Employee:
    def __init__(self, name , salary):
        self.name = input("name")
        self.__salary = int(input(salary))
    
    def bonus(self):
        if self.__salary >= 20000:
            print("Employee is eligible for bonus")
            return self.__salary * 0.2
        else: 
          print("employee is not eligile")
    
    
    def get__name(self):
        return self.name
    
    def set__name(self):
        return self.name
    
    def get__salary(self):
        return self.__salary
    
    def set__salary(self, new_salary):
        if new_salary > 0:
            
            self.__salary = new_salary
    
            return self.__salary
        else:
            print("salary positive add karain")
    def display(self):
        # return self.get__name, self.get__salary
     print("employee name" , self.get__name())
# employee1 = Employee("name", "salary")
# print("Name of Employee :", employee1.get__name())
# print("Salary of Employee", employee1.get__salary())
# print("Bonus of Employee" ,employee1.bonus())

# employee1.salai

class Manager(Employee):
    
    def __init__(self, name, salary):
        # Call parent class constructor
        super().__init__(name, salary)
        # self.set_department("Management") # Using parent's protected method
    
    # Additional methods specific to Manager
    def get_team_size(self):
        return self.__team_size
    
    def set_team_size(self, new_size):
        if new_size > 0:
            self.__team_size = new_size
            return True
        return False
    
    # # Override parent method (polymorphism)
    # def calculate_bonus(self):
    #     """Override: Managers get 10% bonus + extra per team member"""
    #     base_bonus = super().calculate_bonus()  # Call parent method
    #     team_bonus = self.__team_size * 500
    #     return base_bonus + team_bonus
    
    # Override display method
    def display_info(self):
        super().display()  # Call parent display
        # print(f"Team Size: {self.__team_size} members")
        # print(f"Management Bonus: +${self.__team_size * 500:,.2f}")
# employee1.set__salary(-1)

manager1 = Manager("ali", 5 )
manager1.display_info()
manager1.set_team_size(10)
manager1.display_info()
# Out:
# employee name john
# employee name john

# %%
class Manager(Employee):
    def __init__(self , name , salary , team_size):
        self.__name = name
        self.__salary = salary
        self.__team_size = team_size
    Employee.__init__(self):
     
    Employee.bonus =

# %%
class Manager(Employee):
    
    def __init__(self, name, employee_id, salary, team_size):
        # Call parent class constructor
        super().__init__(name, employee_id, salary)
        self.__team_size = team_size      # Private attribute
        self.set_department("Management") # Using parent's protected method
    
    # Additional methods specific to Manager
    def get_team_size(self):
        return self.__team_size
    
    def set_team_size(self, new_size):
        if new_size > 0:
            self.__team_size = new_size
            return True
        return False
    
 
    def display_info(self):
        super().display_info()  # Call parent display
        print(f"Team Size: {self.__team_size} members")
        print(f"Management Bonus: +${self.__team_size * 500:,.2f}")
